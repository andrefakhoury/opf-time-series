# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
datasets_df = pd.read_csv('data/DataSummary.csv')

# %%
df_names = ['FaceFour', 'ChlorineConcentration', 'WordSynonyms', 'Phoneme', 'ElectricDevices']
df_name = df_names[0]
df = pd.read_table(f'data/UCRArchive_2018/{df_name}/{df_name}_TRAIN.tsv', header=None)
df.describe()
# Out:
#              0          1          2          3          4          5    \
# count  24.000000  24.000000  24.000000  24.000000  24.000000  24.000000
# mean    2.208333   2.430645   2.070530   1.851368   1.503907   1.190691
# std     1.141287   0.595471   0.774206   0.698964   0.773207   0.724874
# min     1.000000   0.932723   0.188265   0.188265  -0.329637  -0.329637
# 25%     1.000000   2.168107   1.903075   1.589312   1.060261   0.680015
# 50%     2.000000   2.464945   2.113540   1.980128   1.679690   1.327619
# 75%     3.000000   2.844695   2.557865   2.149786   1.920239   1.568305
# max     4.000000   3.510676   3.244086   3.244086   2.869523   2.869523
#
#              6          7          8          9    ...        341        342  \
# count  24.000000  24.000000  24.000000  24.000000  ...  24.000000  24.000000
# mean    0.969649   0.589316   0.509972   0.342483  ...  -0.422443  -0.409290
# std     0.832180   0.832872   0.932425   1.112166  ...   1.361342   1.358779
# ...

# %%
# datasets_df = pd.read_csv('data/DataSummary.csv')
# datasets_df.loc[datasets_df['Name'] == 'FaceFour'].iloc[:, 7].values[0]

df_names = ['FaceFour', 'EthanolLevel', 'ChlorineConcentration', 'Phoneme', 'ShapesAll', 'TwoPatterns', 'InsectWingbeatSound']

df_names = ['WordSynonyms', 'ChlorineConcentration', 'ShapesAll', 'EthanolLevel', 'FordA']
new_df = datasets_df.loc[datasets_df['Name'].isin(df_names)].set_index('Name')
new_df.loc[df_names].reset_index().drop(columns=['ID'])
# Out:
#                     Name     Type  Train   Test   Class Length  ED (w=0)  \
# 0           WordSynonyms    Image     267    638     25    270    0.3824
# 1  ChlorineConcentration   Sensor     467   3840      3    166    0.3500
# 2              ShapesAll    Image     600    600     60    512    0.2483
# 3           EthanolLevel  Spectro     504    500      4   1751    0.7260
# 4                  FordA   Sensor    3601   1320      2    500    0.3348
#
#   DTW (learned_w)   DTW (w=100)  Default rate      Data donor/editor
# 0       0.2618 (9)       0.3511        0.7806  T. Rath & R. Manmatha
# 1       0.3500 (0)       0.3516        0.4674   L. Li & C. Faloutsos
# 2       0.1980 (4)       0.2317        0.9833  J. Hills & A. Bagnall
# 3       0.7180 (1)       0.7240        0.7480             A. Bagnall
# 4       0.3091 (1)       0.4455        0.4841             A. Bagnall
