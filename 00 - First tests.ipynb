# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_name = 'Worms'

df = pd.read_table(f'data/UCRArchive_2018/{df_name}/{df_name}_TRAIN.tsv', header=None)
df.describe()
# Out:
#               0           1           2           3           4           5    \
# count  181.000000  181.000000  181.000000  181.000000  181.000000  181.000000
# mean     2.353591   -0.054762   -0.055049   -0.053320   -0.044472   -0.046638
# std      1.412976    1.231458    1.217009    1.212576    1.211890    1.212344
# min      1.000000   -3.739104   -3.719033   -3.731076   -3.715019   -3.755160
# 25%      1.000000   -0.854008   -0.831337   -0.804410   -0.804410   -0.855404
# 50%      2.000000    0.004370   -0.034666   -0.055647   -0.033979   -0.012762
# 75%      4.000000    0.764857    0.701450    0.795012    0.845768    0.863678
# max      5.000000    3.482405    3.295940    3.109476    2.923011    2.736547
#
#               6           7           8           9    ...         891  \
# count  181.000000  181.000000  181.000000  181.000000  ...  181.000000
# mean    -0.054311   -0.060297   -0.064308   -0.059014  ...    0.097132
# std      1.211266    1.216288    1.214133    1.209916  ...    1.280118
# min     -3.751146   -3.803328   -3.799314   -3.731076  ...   -3.485523
# 25%     -0.822698   -0.850160   -0.883371   -0.870900  ...   -0.904257
# 50%      0.003513    0.003733   -0.038728   -0.014604  ...    0.101768
# 75%      0.849089    0.857694    0.859221    0.853187  ...    1.130934
# max      2.603414    2.583677    2.563941    2.542011  ...    3.799677
#
#               892         893         894         895         896         897  \
# count  181.000000  181.000000  181.000000  181.000000  181.000000  181.000000
# mean     0.101416    0.102469    0.088442    0.087919    0.075541    0.070701
# std      1.284467    1.264096    1.265234    1.264899    1.274256    1.260681
# min     -3.623585   -3.027088   -3.278430   -3.003730   -3.278430   -3.002307
# 25%     -0.882800   -0.877030   -0.874598   -0.849661   -0.846069   -0.849122
# 50%      0.072891    0.021509    0.045957    0.011206    0.016229   -0.004682
# 75%      1.173048    1.112793    1.082254    1.079085    1.094289    1.049968
# max      3.934791    3.754639    4.024867    3.799677    3.777158    3.777158
#
#               898         899         900
# count  181.000000  181.000000  181.000000
# mean     0.064898    0.064639    0.055676
# std      1.257045    1.278832    1.279609
# min     -2.970360   -2.957012   -3.071337
# 25%     -0.934296   -0.920635   -0.931001
# 50%      0.035938    0.029757    0.029757
# 75%      1.053081    1.072255    1.081842
# max      3.574488    3.844715    3.574488
#
# [8 rows x 901 columns]

# %%
X, Y = df.iloc[:, 1:], df.iloc[:, 0]

# %%
from src.OPFClassifier import OptimumPathForestClassifier

opf = OptimumPathForestClassifier('euclidean-distance')
opf.fit(X, Y)

# %%
df_test = pd.read_table(f'data/UCRArchive_2018/{df_name}/{df_name}_TEST.tsv', header=None)
X_test, Y_test = df_test.iloc[:, 1:], df_test.iloc[:, 0]

# %%
preds = opf.classify(X_test)

# %%
from src.utils import error
error(preds, Y_test)
# Out:
# 0.5454545454545454

# %%
datasets_df = pd.read_csv('data/DataSummary.csv')
x = datasets_df.loc[datasets_df['Name'] == df_name].iloc[:, 7].values[0]

print(f"OPF error: {error(preds, Y_test)}")
print(f"ED (w=0) error: {x}")
# Out:
# OPF error: 0.5454545454545454
# ED (w=0) error: 0.5455
